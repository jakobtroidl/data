# %%
import numpy as np
import zarr
import os

# %%
data = np.load('/Users/jakobtroidl/Desktop/data/test.npy')
out = zarr.open('test.zarr', 'a')
out['data'] = data

# close the zarr file to ensure all data is written
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/compcon/lib/python3.9/site-packages/zarr/hierarchy.py:538, in Group.__getattr__(self, item)
#     537 try:
# --> 538     return self.__getitem__(item)
#     539 except KeyError as e:
#
# File ~/opt/anaconda3/envs/compcon/lib/python3.9/site-packages/zarr/hierarchy.py:511, in Group.__getitem__(self, item)
#     510 else:
# --> 511     raise KeyError(item)
#
# KeyError: 'close'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 6
#       3 out['data'] = data
#       5 # close the zarr file to ensure all data is written
# ----> 6 out.close()
#
# File ~/opt/anaconda3/envs/compcon/lib/python3.9/site-packages/zarr/hierarchy.py:540, in Group.__getattr__(self, item)
# ...
